# %% [markdown]
# # Implementing market basket analysis

# %%
#Loading neccesary packages
import numpy as np
import pandas as pd
from mlxtend.frequent_patterns import apriori
from mlxtend.frequent_patterns import association_rules

# %%
#Reading Data From Web
myretaildata = pd.read_excel('http://archive.ics.uci.edu/ml/machine-learning-databases/00352/Online%20Retail.xlsx')
myretaildata.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice  CustomerID         Country
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 2 2010-12-01 08:26:00       2.75     17850.0  United Kingdom
# 3 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 4 2010-12-01 08:26:00       3.39     17850.0  United Kingdom

# %% [markdown]
# # Data Preparation

# %%
#Data Cleaning
myretaildata['Description'] = myretaildata['Description'].str.strip() #removes spaces from beginning and end
myretaildata.dropna(axis=0, subset=['InvoiceNo'], inplace=True) #removes duplicate invoice
myretaildata['InvoiceNo'] = myretaildata['InvoiceNo'].astype('str') #converting invoice number to be string
myretaildata = myretaildata[~myretaildata['InvoiceNo'].str.contains('C')] #remove the credit transactions 
myretaildata.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice  CustomerID         Country
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 2 2010-12-01 08:26:00       2.75     17850.0  United Kingdom
# 3 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 4 2010-12-01 08:26:00       3.39     17850.0  United Kingdom

# %%
myretaildata['Country'].value_counts()
#myretaildata.shape
# Out:
# United Kingdom          487622
# Germany                   9042
# France                    8408
# EIRE                      7894
# Spain                     2485
# Netherlands               2363
# Belgium                   2031
# Switzerland               1967
# Portugal                  1501
# Australia                 1185
# Norway                    1072
# Italy                      758
# Channel Islands            748
# Finland                    685
# Cyprus                     614
# Sweden                     451
# Unspecified                446
# Austria                    398
# Denmark                    380
# Poland                     330
# Japan                      321
# Israel                     295
# Hong Kong                  284
# Singapore                  222
# Iceland                    182
# USA                        179
# Canada                     151
# Greece                     145
# Malta                      112
# United Arab Emirates        68
# European Community          60
# RSA                         58
# Lebanon                     45
# Lithuania                   35
# Brazil                      32
# Czech Republic              25
# Bahrain                     18
# Saudi Arabia                 9
# Name: Country, dtype: int64

# %%
#Separating transactions for Germany
mybasket = (myretaildata[myretaildata['Country'] =="Germany"]
          .groupby(['InvoiceNo', 'Description'])['Quantity']
          .sum().unstack().reset_index().fillna(0)
          .set_index('InvoiceNo'))

# %%
mybasket
# Out:
# Description  10 COLOUR SPACEBOY PEN  12 COLOURED PARTY BALLOONS  \
# InvoiceNo
# 536527                          0.0                         0.0
# 536840                          0.0                         0.0
# 536861                          0.0                         0.0
# 536967                          0.0                         0.0
# 536983                          0.0                         0.0
# ...                             ...                         ...
# 581266                          0.0                         0.0
# 581494                          0.0                         0.0
# 581570                          0.0                         0.0
# 581574                          0.0                         0.0
# 581578                          0.0                         0.0
#
# Description  12 IVORY ROSE PEG PLACE SETTINGS  \
# InvoiceNo
# 536527                                    0.0
# 536840                                    0.0
# 536861                                    0.0
# 536967                                    0.0
# 536983                                    0.0
# ...                                       ...
# 581266                                    0.0
# 581494                                    0.0
# 581570                                    0.0
# 581574                                    0.0
# 581578                                    0.0
#
# Description  12 MESSAGE CARDS WITH ENVELOPES  12 PENCIL SMALL TUBE WOODLAND  \
# InvoiceNo
# 536527                                   0.0                            0.0
# 536840                                   0.0                            0.0
# 536861                                   0.0                            0.0
# 536967                                   0.0                            0.0
# 536983                                   0.0                            0.0
# ...                                      ...                            ...
# 581266                                   0.0                            0.0
# 581494                                   0.0                            0.0
# 581570                                   0.0                            0.0
# 581574                                   0.0                            0.0
# 581578                                   0.0                            0.0
#
# Description  12 PENCILS SMALL TUBE RED RETROSPOT  12 PENCILS SMALL TUBE SKULL  \
# InvoiceNo
# 536527                                       0.0                          0.0
# 536840                                       0.0                          0.0
# 536861                                       0.0                          0.0
# 536967                                       0.0                          0.0
# 536983                                       0.0                          0.0
# ...                                          ...                          ...
# 581266                                       0.0                          0.0
# 581494                                       0.0                          0.0
# 581570                                       0.0                          0.0
# 581574                                       0.0                          0.0
# 581578                                       0.0                          0.0
#
# Description  12 PENCILS TALL TUBE POSY  12 PENCILS TALL TUBE RED RETROSPOT  \
# InvoiceNo
# 536527                             0.0                                 0.0
# 536840                             0.0                                 0.0
# 536861                             0.0                                 0.0
# 536967                             0.0                                 0.0
# 536983                             0.0                                 0.0
# ...                                ...                                 ...
# 581266                             0.0                                 0.0
# 581494                             0.0                                 0.0
# 581570                             0.0                                 0.0
# 581574                             0.0                                 0.0
# 581578                             0.0                                 0.0
#
# Description  12 PENCILS TALL TUBE SKULLS  ...  YULETIDE IMAGES GIFT WRAP SET  \
# InvoiceNo                                 ...
# 536527                               0.0  ...                            0.0
# 536840                               0.0  ...                            0.0
# 536861                               0.0  ...                            0.0
# 536967                               0.0  ...                            0.0
# 536983                               0.0  ...                            0.0
# ...                                  ...  ...                            ...
# 581266                               0.0  ...                            0.0
# 581494                               0.0  ...                            0.0
# 581570                               0.0  ...                            0.0
# 581574                               0.0  ...                            0.0
# 581578                               0.0  ...                            0.0
#
# Description  ZINC  HEART T-LIGHT HOLDER  ZINC  STAR T-LIGHT HOLDER  \
# InvoiceNo
# 536527                              0.0                        0.0
# 536840                              0.0                        0.0
# 536861                              0.0                        0.0
# 536967                              0.0                        0.0
# 536983                              0.0                        0.0
# ...                                 ...                        ...
# 581266                              0.0                        0.0
# 581494                              0.0                        0.0
# 581570                              0.0                        0.0
# 581574                              0.0                        0.0
# 581578                              0.0                        0.0
#
# Description  ZINC BOX SIGN HOME  ZINC FOLKART SLEIGH BELLS  \
# InvoiceNo
# 536527                      0.0                        0.0
# 536840                      0.0                        0.0
# 536861                      0.0                        0.0
# 536967                      0.0                        0.0
# 536983                      0.0                        0.0
# ...                         ...                        ...
# 581266                      0.0                        0.0
# 581494                      0.0                        0.0
# 581570                      0.0                        0.0
# 581574                      0.0                        0.0
# 581578                      0.0                        0.0
#
# Description  ZINC HEART LATTICE T-LIGHT HOLDER  ZINC METAL HEART DECORATION  \
# InvoiceNo
# 536527                                     0.0                          0.0
# 536840                                     0.0                          0.0
# 536861                                     0.0                          0.0
# 536967                                     0.0                          0.0
# 536983                                     0.0                          0.0
# ...                                        ...                          ...
# 581266                                     0.0                          0.0
# 581494                                     0.0                          0.0
# 581570                                     0.0                          0.0
# 581574                                     0.0                          0.0
# 581578                                     0.0                          0.0
#
# Description  ZINC T-LIGHT HOLDER STAR LARGE  ZINC T-LIGHT HOLDER STARS SMALL  \
# InvoiceNo
# 536527                                  0.0                              0.0
# 536840                                  0.0                              0.0
# 536861                                  0.0                              0.0
# 536967                                  0.0                              0.0
# 536983                                  0.0                              0.0
# ...                                     ...                              ...
# 581266                                  0.0                              0.0
# 581494                                  0.0                              0.0
# 581570                                  0.0                              0.0
# 581574                                  0.0                              0.0
# 581578                                  0.0                              0.0
#
# Description  ZINC WILLIE WINKIE  CANDLE STICK
# InvoiceNo
# 536527                                    0.0
# 536840                                    0.0
# 536861                                    0.0
# 536967                                    0.0
# 536983                                    0.0
# ...                                       ...
# 581266                                    0.0
# 581494                                    0.0
# 581570                                    0.0
# 581574                                    0.0
# 581578                                    0.0
#
# [457 rows x 1695 columns]

# %%
#viewing transaction basket
mybasket.head()
# Out:
# Description  10 COLOUR SPACEBOY PEN  12 COLOURED PARTY BALLOONS  \
# InvoiceNo
# 536527                          0.0                         0.0
# 536840                          0.0                         0.0
# 536861                          0.0                         0.0
# 536967                          0.0                         0.0
# 536983                          0.0                         0.0
#
# Description  12 IVORY ROSE PEG PLACE SETTINGS  \
# InvoiceNo
# 536527                                    0.0
# 536840                                    0.0
# 536861                                    0.0
# 536967                                    0.0
# 536983                                    0.0
#
# Description  12 MESSAGE CARDS WITH ENVELOPES  12 PENCIL SMALL TUBE WOODLAND  \
# InvoiceNo
# 536527                                   0.0                            0.0
# 536840                                   0.0                            0.0
# 536861                                   0.0                            0.0
# 536967                                   0.0                            0.0
# 536983                                   0.0                            0.0
#
# Description  12 PENCILS SMALL TUBE RED RETROSPOT  12 PENCILS SMALL TUBE SKULL  \
# InvoiceNo
# 536527                                       0.0                          0.0
# 536840                                       0.0                          0.0
# 536861                                       0.0                          0.0
# 536967                                       0.0                          0.0
# 536983                                       0.0                          0.0
#
# Description  12 PENCILS TALL TUBE POSY  12 PENCILS TALL TUBE RED RETROSPOT  \
# InvoiceNo
# 536527                             0.0                                 0.0
# 536840                             0.0                                 0.0
# 536861                             0.0                                 0.0
# 536967                             0.0                                 0.0
# 536983                             0.0                                 0.0
#
# Description  12 PENCILS TALL TUBE SKULLS  ...  YULETIDE IMAGES GIFT WRAP SET  \
# InvoiceNo                                 ...
# 536527                               0.0  ...                            0.0
# 536840                               0.0  ...                            0.0
# 536861                               0.0  ...                            0.0
# 536967                               0.0  ...                            0.0
# 536983                               0.0  ...                            0.0
#
# Description  ZINC  HEART T-LIGHT HOLDER  ZINC  STAR T-LIGHT HOLDER  \
# InvoiceNo
# 536527                              0.0                        0.0
# 536840                              0.0                        0.0
# 536861                              0.0                        0.0
# 536967                              0.0                        0.0
# 536983                              0.0                        0.0
#
# Description  ZINC BOX SIGN HOME  ZINC FOLKART SLEIGH BELLS  \
# InvoiceNo
# 536527                      0.0                        0.0
# 536840                      0.0                        0.0
# 536861                      0.0                        0.0
# 536967                      0.0                        0.0
# 536983                      0.0                        0.0
#
# Description  ZINC HEART LATTICE T-LIGHT HOLDER  ZINC METAL HEART DECORATION  \
# InvoiceNo
# 536527                                     0.0                          0.0
# 536840                                     0.0                          0.0
# 536861                                     0.0                          0.0
# 536967                                     0.0                          0.0
# 536983                                     0.0                          0.0
#
# Description  ZINC T-LIGHT HOLDER STAR LARGE  ZINC T-LIGHT HOLDER STARS SMALL  \
# InvoiceNo
# 536527                                  0.0                              0.0
# 536840                                  0.0                              0.0
# 536861                                  0.0                              0.0
# 536967                                  0.0                              0.0
# 536983                                  0.0                              0.0
#
# Description  ZINC WILLIE WINKIE  CANDLE STICK
# InvoiceNo
# 536527                                    0.0
# 536840                                    0.0
# 536861                                    0.0
# 536967                                    0.0
# 536983                                    0.0
#
# [5 rows x 1695 columns]

# %%
#converting all positive vaues to 1 and everything else to 0
def my_encode_units(x):
    if x <= 0:
        return 0
    if x >= 1:
        return 1

my_basket_sets = mybasket.applymap(my_encode_units)
#my_basket_sets.drop('POSTAGE', inplace=True, axis=1) #Remove "postage" as an item

# %% [markdown]
# # Training Model

# %%
#Generatig frequent itemsets
my_frequent_itemsets = apriori(my_basket_sets, min_support=0.07, use_colnames=True)

# %%
#generating rules
my_rules = association_rules(my_frequent_itemsets, metric="lift", min_threshold=1)

# %%
#viewing top 100 rules
my_rules.head(100)
# Out:
#                                           antecedents  \
# 0                            (6 RIBBONS RUSTIC CHARM)
# 1                                           (POSTAGE)
# 2                        (JUMBO BAG WOODLAND ANIMALS)
# 3                                           (POSTAGE)
# 4                     (PLASTERS IN TIN CIRCUS PARADE)
# 5                                           (POSTAGE)
# 6                          (PLASTERS IN TIN SPACEBOY)
# 7                                           (POSTAGE)
# 8                  (PLASTERS IN TIN WOODLAND ANIMALS)
# 9                                           (POSTAGE)
# 10                 (PLASTERS IN TIN WOODLAND ANIMALS)
# 11               (ROUND SNACK BOXES SET OF4 WOODLAND)
# 12                    (RED TOADSTOOL LED NIGHT LIGHT)
# 13                                          (POSTAGE)
# 14                         (REGENCY CAKESTAND 3 TIER)
# 15                                          (POSTAGE)
# 16                (ROUND SNACK BOXES SET OF 4 FRUITS)
# 17                                          (POSTAGE)
# 18               (ROUND SNACK BOXES SET OF4 WOODLAND)
# 19                                          (POSTAGE)
# 20                               (SPACEBOY LUNCH BOX)
# 21                                          (POSTAGE)
# 22                           (WOODLAND CHARLOTTE BAG)
# 23                                          (POSTAGE)
# 24                (ROUND SNACK BOXES SET OF 4 FRUITS)
# 25               (ROUND SNACK BOXES SET OF4 WOODLAND)
# 26                               (SPACEBOY LUNCH BOX)
# 27               (ROUND SNACK BOXES SET OF4 WOODLAND)
# 28  (ROUND SNACK BOXES SET OF 4 FRUITS, ROUND SNAC...
# 29       (ROUND SNACK BOXES SET OF 4 FRUITS, POSTAGE)
# 30      (ROUND SNACK BOXES SET OF4 WOODLAND, POSTAGE)
# 31                (ROUND SNACK BOXES SET OF 4 FRUITS)
# 32               (ROUND SNACK BOXES SET OF4 WOODLAND)
# 33                                          (POSTAGE)
#
#                                           consequents  antecedent support  \
# 0                                           (POSTAGE)            0.102845
# 1                            (6 RIBBONS RUSTIC CHARM)            0.818381
# 2                                           (POSTAGE)            0.100656
# 3                        (JUMBO BAG WOODLAND ANIMALS)            0.818381
# 4                                           (POSTAGE)            0.115974
# 5                     (PLASTERS IN TIN CIRCUS PARADE)            0.818381
# 6                                           (POSTAGE)            0.107221
# 7                          (PLASTERS IN TIN SPACEBOY)            0.818381
# 8                                           (POSTAGE)            0.137856
# 9                  (PLASTERS IN TIN WOODLAND ANIMALS)            0.818381
# 10               (ROUND SNACK BOXES SET OF4 WOODLAND)            0.137856
# 11                 (PLASTERS IN TIN WOODLAND ANIMALS)            0.245077
# 12                                          (POSTAGE)            0.096280
# 13                    (RED TOADSTOOL LED NIGHT LIGHT)            0.818381
# 14                                          (POSTAGE)            0.137856
# 15                         (REGENCY CAKESTAND 3 TIER)            0.818381
# 16                                          (POSTAGE)            0.157549
# 17                (ROUND SNACK BOXES SET OF 4 FRUITS)            0.818381
# 18                                          (POSTAGE)            0.245077
# 19               (ROUND SNACK BOXES SET OF4 WOODLAND)            0.818381
# 20                                          (POSTAGE)            0.102845
# 21                               (SPACEBOY LUNCH BOX)            0.818381
# 22                                          (POSTAGE)            0.126915
# 23                           (WOODLAND CHARLOTTE BAG)            0.818381
# 24               (ROUND SNACK BOXES SET OF4 WOODLAND)            0.157549
# 25                (ROUND SNACK BOXES SET OF 4 FRUITS)            0.245077
# 26               (ROUND SNACK BOXES SET OF4 WOODLAND)            0.102845
# 27                               (SPACEBOY LUNCH BOX)            0.245077
# 28                                          (POSTAGE)            0.131291
# 29               (ROUND SNACK BOXES SET OF4 WOODLAND)            0.150985
# 30                (ROUND SNACK BOXES SET OF 4 FRUITS)            0.225383
# 31      (ROUND SNACK BOXES SET OF4 WOODLAND, POSTAGE)            0.157549
# 32       (ROUND SNACK BOXES SET OF 4 FRUITS, POSTAGE)            0.245077
# 33  (ROUND SNACK BOXES SET OF 4 FRUITS, ROUND SNAC...            0.818381
#
#     consequent support   support  confidence      lift  leverage  conviction
# 0             0.818381  0.091904    0.893617  1.091933  0.007738    1.707221
# 1             0.102845  0.091904    0.112299  1.091933  0.007738    1.010651
# 2             0.818381  0.087527    0.869565  1.062544  0.005152    1.392414
# 3             0.100656  0.087527    0.106952  1.062544  0.005152    1.007049
# 4             0.818381  0.100656    0.867925  1.060539  0.005746    1.375117
# 5             0.115974  0.100656    0.122995  1.060539  0.005746    1.008006
# 6             0.818381  0.100656    0.938776  1.147113  0.012909    2.966448
# 7             0.107221  0.100656    0.122995  1.147113  0.012909    1.017986
# 8             0.818381  0.118162    0.857143  1.047364  0.005344    1.271335
# 9             0.137856  0.118162    0.144385  1.047364  0.005344    1.007631
# 10            0.245077  0.074398    0.539683  2.202098  0.040613    1.640006
# 11            0.137856  0.074398    0.303571  2.202098  0.040613    1.237951
# 12            0.818381  0.080963    0.840909  1.027528  0.002169    1.141607
# 13            0.096280  0.080963    0.098930  1.027528  0.002169    1.002941
# 14            0.818381  0.120350    0.873016  1.066760  0.007532    1.430252
# 15            0.137856  0.120350    0.147059  1.066760  0.007532    1.010790
# 16            0.818381  0.150985    0.958333  1.171012  0.022049    4.358862
# 17            0.157549  0.150985    0.184492  1.171012  0.022049    1.033038
# 18            0.818381  0.225383    0.919643  1.123735  0.024817    2.260151
# 19            0.245077  0.225383    0.275401  1.123735  0.024817    1.041850
# 20            0.818381  0.091904    0.893617  1.091933  0.007738    1.707221
# 21            0.102845  0.091904    0.112299  1.091933  0.007738    1.010651
# 22            0.818381  0.115974    0.913793  1.116587  0.012109    2.106783
# 23            0.126915  0.115974    0.141711  1.116587  0.012109    1.017240
# 24            0.245077  0.131291    0.833333  3.400298  0.092679    4.529540
# 25            0.157549  0.131291    0.535714  3.400298  0.092679    1.814509
# 26            0.245077  0.070022    0.680851  2.778116  0.044817    2.365427
# 27            0.102845  0.070022    0.285714  2.778116  0.044817    1.256018
# 28            0.818381  0.124726    0.950000  1.160829  0.017280    3.632385
# 29            0.245077  0.124726    0.826087  3.370730  0.087724    4.340810
# 30            0.157549  0.124726    0.553398  3.512540  0.089218    1.886357
# 31            0.225383  0.124726    0.791667  3.512540  0.089218    3.718162
# 32            0.150985  0.124726    0.508929  3.370730  0.087724    1.728904
# 33            0.131291  0.124726    0.152406  1.160829  0.017280    1.024912

# %% [markdown]
# # Making reecommendations

# %%
my_basket_sets['ROUND SNACK BOXES SET OF4 WOODLAND'].sum()
# Out:
# 112

# %%
my_basket_sets['SPACEBOY LUNCH BOX'].sum()
# Out:
# 47

# %%
#Filtering rules based on condition
my_rules[ (my_rules['lift'] >= 3) &
       (my_rules['confidence'] >= 0.3) ]
# Out:
#                                       antecedents  \
# 24            (ROUND SNACK BOXES SET OF 4 FRUITS)
# 25           (ROUND SNACK BOXES SET OF4 WOODLAND)
# 29   (ROUND SNACK BOXES SET OF 4 FRUITS, POSTAGE)
# 30  (ROUND SNACK BOXES SET OF4 WOODLAND, POSTAGE)
# 31            (ROUND SNACK BOXES SET OF 4 FRUITS)
# 32           (ROUND SNACK BOXES SET OF4 WOODLAND)
#
#                                       consequents  antecedent support  \
# 24           (ROUND SNACK BOXES SET OF4 WOODLAND)            0.157549
# 25            (ROUND SNACK BOXES SET OF 4 FRUITS)            0.245077
# 29           (ROUND SNACK BOXES SET OF4 WOODLAND)            0.150985
# 30            (ROUND SNACK BOXES SET OF 4 FRUITS)            0.225383
# 31  (ROUND SNACK BOXES SET OF4 WOODLAND, POSTAGE)            0.157549
# 32   (ROUND SNACK BOXES SET OF 4 FRUITS, POSTAGE)            0.245077
#
#     consequent support   support  confidence      lift  leverage  conviction
# 24            0.245077  0.131291    0.833333  3.400298  0.092679    4.529540
# 25            0.157549  0.131291    0.535714  3.400298  0.092679    1.814509
# 29            0.245077  0.124726    0.826087  3.370730  0.087724    4.340810
# 30            0.157549  0.124726    0.553398  3.512540  0.089218    1.886357
# 31            0.225383  0.124726    0.791667  3.512540  0.089218    3.718162
# 32            0.150985  0.124726    0.508929  3.370730  0.087724    1.728904
